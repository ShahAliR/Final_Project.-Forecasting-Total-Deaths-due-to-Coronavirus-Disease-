# %% [markdown]
# # Descriptive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('covid_data2.csv')
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-03-23         40.0        6.0
# 1      AFG      Asia  Afghanistan  2020-03-24         42.0        2.0
# 2      AFG      Asia  Afghanistan  2020-03-25         74.0       32.0
# 3      AFG      Asia  Afghanistan  2020-03-26         80.0        6.0
# 4      AFG      Asia  Afghanistan  2020-03-27         91.0       11.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           1.0         1.0                    0.998               0.000006
# 1           1.0         0.0                    1.047               0.000002
# 2           1.0         0.0                    1.845               0.000032
# 3           2.0         1.0                    1.995               0.000006
# 4           2.0         0.0                    2.269               0.000011
#
#    ...  extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
df1= pd.read_csv('covidforln.csv')

# %%
df1
# Out:
#     iso_code continent            country  total_cases  new_cases  \
# 0        AFG      Asia        Afghanistan      55174.0       53.0
# 1        ALB    Europe            Albania      75454.0      887.0
# 2        DZA    Africa            Algeria     105124.0      272.0
# 3        AND    Europe            Andorra      10070.0       53.0
# 4        AGO    Africa             Angola      20381.0       15.0
# ..       ...       ...                ...          ...        ...
# 209      VNM      Asia            Vietnam       2962.0       20.0
# 210      WLF   Oceania  Wallis and Futuna        454.0        0.0
# 211      YEM      Asia              Yemen       2255.0       34.0
# 212      ZMB    Africa             Zambia      64610.0     1037.0
# 213      ZWE    Africa           Zimbabwe     257893.0        0.0
#
#      total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0          2406.0         1.0                 1375.929               0.000053
# ...

# %%
# Exploratory data analysis using matplotlib

# %%
#!pip3 install seaborn if you need to
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data.rename(columns={ 'location' :'country'}, inplace=True)

# %%
data
# Out:
#        iso_code continent      country        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-03-23         40.0        6.0
# 1           AFG      Asia  Afghanistan  2020-03-24         42.0        2.0
# 2           AFG      Asia  Afghanistan  2020-03-25         74.0       32.0
# 3           AFG      Asia  Afghanistan  2020-03-26         80.0        6.0
# 4           AFG      Asia  Afghanistan  2020-03-27         91.0       11.0
# ...         ...       ...          ...         ...          ...        ...
# 185131      ZWE    Africa     Zimbabwe  2022-10-23     257893.0        0.0
# 185132      ZWE    Africa     Zimbabwe  2022-10-24     257893.0        0.0
# 185133      ZWE    Africa     Zimbabwe  2022-10-25     257893.0        0.0
# 185134      ZWE    Africa     Zimbabwe  2022-10-26     257893.0        0.0
# 185135      ZWE    Africa     Zimbabwe  2022-10-27     257893.0        0.0
#
#         total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
data.sort_values('country')
data['cid'] = (data.groupby(['country']).cumcount()==0).astype(int)
 
data['cid'] = data['cid'].cumsum()

# %%
FR=data.loc[data['cid'] == 70]

# %%
FR
# Out:
#       iso_code continent country        date  total_cases  new_cases  \
# 61871      FRA    Europe  France  2020-02-15         12.0        1.0
# 61872      FRA    Europe  France  2020-02-16         12.0        0.0
# 61873      FRA    Europe  France  2020-02-17         12.0        0.0
# 61874      FRA    Europe  France  2020-02-18         12.0        0.0
# 61875      FRA    Europe  France  2020-02-19         12.0        0.0
# ...        ...       ...     ...         ...          ...        ...
# 62835      FRA    Europe  France  2022-10-23   36586874.0        0.0
# 62836      FRA    Europe  France  2022-10-24   36668997.0    82123.0
# 62837      FRA    Europe  France  2022-10-25   36728705.0    59708.0
# 62838      FRA    Europe  France  2022-10-26   36769890.0    41185.0
# 62839      FRA    Europe  France  2022-10-27   36806979.0    37089.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 61871           1.0         1.0                    0.178
# ...

# %%
LU.to_csv("C:/Users/Yuga 14/Desktop/final project/crona/covid_LU.csv", index=False)#NL,DE,FR,UK,TU,SP,PO,LU

# %%
ih_countries= pd.concat([NL,DE,FR,UK,TU,SP,PO,LU],ignore_index=True)

# %%
ih_countries.to_csv("C:/Users/Yuga 14/Desktop/final project/crona/covid_ih_countries.csv", index=False)

# %%
ih_countries
# Out:
#      iso_code continent      country        date  total_cases  new_cases  \
# 0         NLD    Europe  Netherlands  2020-03-06        188.0       60.0
# 1         NLD    Europe  Netherlands  2020-03-07        265.0       77.0
# 2         NLD    Europe  Netherlands  2020-03-08        321.0       56.0
# 3         NLD    Europe  Netherlands  2020-03-09        382.0       61.0
# 4         NLD    Europe  Netherlands  2020-03-10        503.0      121.0
# ...       ...       ...          ...         ...          ...        ...
# 7690      LUX    Europe   Luxembourg  2022-10-23     300099.0        0.0
# 7691      LUX    Europe   Luxembourg  2022-10-24     300436.0      337.0
# 7692      LUX    Europe   Luxembourg  2022-10-25     301031.0      595.0
# 7693      LUX    Europe   Luxembourg  2022-10-26     301353.0      322.0
# 7694      LUX    Europe   Luxembourg  2022-10-27     301761.0      408.0
#
#       total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
NL['total_cases'].value_counts()
# Out:
# 8463695.0    4
# 8407705.0    4
# 8416314.0    4
# 8412006.0    3
# 8426196.0    3
#             ..
# 867789.0     1
# 874401.0     1
# 879818.0     1
# 884710.0     1
# 8516114.0    1
# Name: total_cases, Length: 902, dtype: int64

# %%
# everything can be a bar chart, but that is a sad sad world
sns.barplot(x="new_cases", y="total_deaths", data=NL)
plt.show()

# %%
NL.sort_values('new_deaths', ascending=False)
# Out:
#        iso_code continent      country        date  total_cases  new_cases  \
# 120805      NLD    Europe  Netherlands  2020-04-07      20589.0      972.0
# 120813      NLD    Europe  Netherlands  2020-04-15      29267.0     1062.0
# 121074      NLD    Europe  Netherlands  2021-01-05     842667.0     7138.0
# 120814      NLD    Europe  Netherlands  2020-04-16      30506.0     1239.0
# 120798      NLD    Europe  Netherlands  2020-03-31      13620.0     1019.0
# ...         ...       ...          ...         ...          ...        ...
# 121500      NLD    Europe  Netherlands  2022-03-07    6781229.0    64454.0
# 121631      NLD    Europe  Netherlands  2022-07-17    8284784.0        0.0
# 121630      NLD    Europe  Netherlands  2022-07-16    8284784.0        0.0
# 120916      NLD    Europe  Netherlands  2020-07-31      54860.0      433.0
# 121658      NLD    Europe  Netherlands  2022-08-13    8373241.0        0.0
#
#         total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
NL.sort_values('new_deaths', ascending=False)
NL['Black_days'] = NL['new_deaths']>175
NL.sort_values('new_deaths', ascending=False)
NL.head()
# Out:
#        iso_code continent      country        date  total_cases  new_cases  \
# 120773      NLD    Europe  Netherlands  2020-03-06        188.0       60.0
# 120774      NLD    Europe  Netherlands  2020-03-07        265.0       77.0
# 120775      NLD    Europe  Netherlands  2020-03-08        321.0       56.0
# 120776      NLD    Europe  Netherlands  2020-03-09        382.0       61.0
# 120777      NLD    Europe  Netherlands  2020-03-10        503.0      121.0
#
#         total_deaths  new_deaths  total_cases_per_million  \
# 120773           1.0         1.0                   10.742
# 120774           1.0         0.0                   15.141
# 120775           3.0         2.0                   18.341
# 120776           3.0         0.0                   21.826
# 120777           4.0         1.0                   28.740
#
#         new_cases_per_million  ...  diabetes_prevalence  female_smokers  \
# 120773               0.000060  ...                 5.29            24.4
# ...

# %%
NL=NL.drop(['donated_big'], axis=1)

# %%
# distributions can shed a bit more light than boxplots, but are not as succint
sns.distplot(NL['new_deaths'], bins=50)
plt.show()
# Out:
# C:\IronHack\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
NL['new_deaths'].hist(bins=100)
plt.show()

# %%
#scatterplots are great to compare two distinct variables and see if they are somehow related!
sns.scatterplot(x=NL['stringency_index'], y=NL['new_deaths'])
plt.show()

# %%
#scatterplots are great to compare two distinct variables and see if they are somehow related!
sns.scatterplot(x=NL['new_deaths'], y=NL['total_deaths'])
plt.show()

# %%
#finally, some notions on correlation: is our dataset generally independent or are we seeing the same thing over and over?
# when not specified, always shows Pearson correlation
correlations_matrix = NL.corr()
correlations_matrix
# Out:
#                                        total_cases  new_cases  total_deaths  \
# total_cases                               1.000000   0.183782      0.806272
# new_cases                                 0.183782   1.000000      0.267579
# total_deaths                              0.806272   0.267579      1.000000
# new_deaths                               -0.376396  -0.035353     -0.401034
# total_cases_per_million                   1.000000   0.183782      0.806272
# new_cases_per_million                     0.183782   1.000000      0.267579
# total_deaths_per_million                  0.806272   0.267579      1.000000
# new_deaths_per_million                   -0.376396  -0.035353     -0.401034
# new_vaccinations_smoothed_per_million    -0.147157   0.051643      0.212775
# stringency_index                         -0.789594  -0.051551     -0.578052
# population_density                             NaN        NaN           NaN
# ...

# %%
sns.heatmap(correlations_matrix, annot=True)
plt.show()
